# %%
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, f1_score
#preparation de donnees
train_dir = 'D:/Data-Chest-ray/train'
val_dir = 'D:/Data-Chest-ray/val'
test_dir = 'D:/Data-Chest-ray/test'
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=15,
                                   zoom_range=0.1,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1)
val_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(train_dir, target_size=IMG_SIZE,
                                              batch_size=BATCH_SIZE, class_mode='categorical')
val_gen = val_datagen.flow_from_directory(val_dir, target_size=IMG_SIZE,
                                          batch_size=BATCH_SIZE, class_mode='categorical')
test_gen = val_datagen.flow_from_directory(test_dir, target_size=IMG_SIZE,
                                           batch_size=1, class_mode='categorical', shuffle=False)
#Entraînement initial (feature extraction)

base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

model = models.Sequential([
    base_model,
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(train_gen.num_classes, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history_1 = model.fit(train_gen,
                      validation_data=val_gen,
                      epochs=20,
                      callbacks=[early_stop])
#Fine-tuning
# Débloquer les dernières couches de VGG16
base_model.trainable = True
for layer in base_model.layers[:-4]:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history_2 = model.fit(train_gen,
                      validation_data=val_gen,
                      epochs=15,
                      callbacks=[early_stop])

# Prédictions
pred_probs = model.predict(test_gen)
y_pred = np.argmax(pred_probs, axis=1)
y_true = test_gen.classes
target_names = list(test_gen.class_indices.keys())

# Rapport de classification
print(classification_report(y_true, y_pred, target_names=target_names))

# F1-score
f1 = f1_score(y_true, y_pred, average='macro')
print("F1-score (macro):", f1)

# Matrice de confusion
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Courbes ROC pour chaque classe
fpr, tpr, roc_auc = dict(), dict(), dict()
for i in range(len(target_names)):
    fpr[i], tpr[i], _ = roc_curve(test_gen.labels == i, pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure()
for i in range(len(target_names)):
    plt.plot(fpr[i], tpr[i], label=f'{target_names[i]} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (per class)')
plt.legend()
plt.grid(True)
plt.show()
def plot_learning_curves(history_list, labels):
    acc = []
    val_acc = []
    loss = []
    val_loss = []

    for hist in history_list:
        acc += hist.history['accuracy']
        val_acc += hist.history['val_accuracy']
        loss += hist.history['loss']
        val_loss += hist.history['val_loss']

    epochs_range = range(1, len(acc)+1)

    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# Appeler la fonction
plot_learning_curves([history_1, history_2], ['Phase 1', 'Phase 2'])
# Out:
# Found 7750 images belonging to 2 classes.
# Found 744 images belonging to 2 classes.
# Found 364 images belonging to 2 classes.
# C:\Users\Bsi\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 586s 2s/step - accuracy: 0.8904 - loss: 0.2618 - val_accuracy: 0.9234 - val_loss: 0.1480
# Epoch 2/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 574s 2s/step - accuracy: 0.9539 - loss: 0.1225 - val_accuracy: 0.9368 - val_loss: 0.1274
# Epoch 3/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 578s 2s/step - accuracy: 0.9575 - loss: 0.1180 - val_accuracy: 0.9839 - val_loss: 0.0961
# Epoch 4/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 583s 2s/step - accuracy: 0.9652 - loss: 0.0960 - val_accuracy: 0.9328 - val_loss: 0.1329
# Epoch 5/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 577s 2s/step - accuracy: 0.9665 - loss: 0.0943 - val_accuracy: 0.9839 - val_loss: 0.0909
# Epoch 6/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 577s 2s/step - accuracy: 0.9718 - loss: 0.0790 - val_accuracy: 0.9812 - val_loss: 0.0976
# Epoch 7/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 580s 2s/step - accuracy: 0.9693 - loss: 0.0847 - val_accuracy: 0.9812 - val_loss: 0.0903
# Epoch 8/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 573s 2s/step - accuracy: 0.9730 - loss: 0.0710 - val_accuracy: 0.9839 - val_loss: 0.0959
# Epoch 9/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 574s 2s/step - accuracy: 0.9763 - loss: 0.0734 - val_accuracy: 0.9866 - val_loss: 0.0649
# Epoch 10/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 574s 2s/step - accuracy: 0.9764 - loss: 0.0618 - val_accuracy: 0.9677 - val_loss: 0.1125
# Epoch 11/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 569s 2s/step - accuracy: 0.9774 - loss: 0.0625 - val_accuracy: 0.9382 - val_loss: 0.0971
# Epoch 12/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 570s 2s/step - accuracy: 0.9745 - loss: 0.0669 - val_accuracy: 0.9812 - val_loss: 0.0855
# Epoch 13/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 573s 2s/step - accuracy: 0.9785 - loss: 0.0603 - val_accuracy: 0.9731 - val_loss: 0.1153
# Epoch 14/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 574s 2s/step - accuracy: 0.9772 - loss: 0.0708 - val_accuracy: 0.9825 - val_loss: 0.0758
# Epoch 1/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 668s 3s/step - accuracy: 0.9752 - loss: 0.0662 - val_accuracy: 0.9839 - val_loss: 0.0726
# Epoch 2/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 666s 3s/step - accuracy: 0.9821 - loss: 0.0484 - val_accuracy: 0.9409 - val_loss: 0.1418
# Epoch 3/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 664s 3s/step - accuracy: 0.9893 - loss: 0.0336 - val_accuracy: 0.8683 - val_loss: 0.3614
# Epoch 4/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 668s 3s/step - accuracy: 0.9872 - loss: 0.0409 - val_accuracy: 0.9839 - val_loss: 0.0697
# Epoch 5/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 667s 3s/step - accuracy: 0.9881 - loss: 0.0296 - val_accuracy: 0.9489 - val_loss: 0.1057
# Epoch 6/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 665s 3s/step - accuracy: 0.9895 - loss: 0.0278 - val_accuracy: 0.9785 - val_loss: 0.0805
# Epoch 7/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 669s 3s/step - accuracy: 0.9933 - loss: 0.0210 - val_accuracy: 0.9839 - val_loss: 0.0802
# Epoch 8/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 671s 3s/step - accuracy: 0.9897 - loss: 0.0284 - val_accuracy: 0.9839 - val_loss: 0.0695
# Epoch 9/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 667s 3s/step - accuracy: 0.9937 - loss: 0.0214 - val_accuracy: 0.9839 - val_loss: 0.0698
# Epoch 10/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 671s 3s/step - accuracy: 0.9930 - loss: 0.0231 - val_accuracy: 0.8858 - val_loss: 0.3452
# Epoch 11/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 670s 3s/step - accuracy: 0.9930 - loss: 0.0207 - val_accuracy: 0.9839 - val_loss: 0.0770
# Epoch 12/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 674s 3s/step - accuracy: 0.9968 - loss: 0.0127 - val_accuracy: 0.9758 - val_loss: 0.1000
# Epoch 13/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 689s 3s/step - accuracy: 0.9945 - loss: 0.0135 - val_accuracy: 0.9798 - val_loss: 0.0942
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 49s 134ms/step
#               precision    recall  f1-score   support
#
#       NORMAL       0.99      0.77      0.87       182
#    PNEUMONIA       0.81      0.99      0.89       182
#
#     accuracy                           0.88       364
#    macro avg       0.90      0.88      0.88       364
# weighted avg       0.90      0.88      0.88       364
#
# F1-score (macro): 0.8804962779156327

# %%
import matplotlib.pyplot as plt

fig_dir = 'D:/Data-Chest-ray'
os.makedirs(fig_dir, exist_ok=True)

# Courbe d'apprentissage
def save_learning_curves(history_list, save_path):
    acc, val_acc, loss, val_loss = [], [], [], []
    for hist in history_list:
        acc += hist.history['accuracy']
        val_acc += hist.history['val_accuracy']
        loss += hist.history['loss']
        val_loss += hist.history['val_loss']

    epochs = range(1, len(acc)+1)

    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, label='Training Accuracy')
    plt.plot(epochs, val_acc, label='Validation Accuracy')
    plt.title('Accuracy over Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, label='Training Loss')
    plt.plot(epochs, val_loss, label='Validation Loss')
    plt.title('Loss over Epochs')
    plt.legend()

    plt.savefig(os.path.join(save_path, 'learning_curves.png'))
    plt.close()

save_learning_curves([history_1, history_2], fig_dir)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.savefig(os.path.join(fig_dir, 'confusion_matrix.png'))
plt.close()
plt.figure()
for i in range(len(target_names)):
    plt.plot(fpr[i], tpr[i], label=f'{target_names[i]} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(fig_dir, 'roc_curve.png'))
plt.close()

# %%
# save
model_save_path = 'D:/Data-Chest-ray'
os.makedirs(model_save_path, exist_ok=True)

# Sauvegarder le modèle final
model.save(os.path.join(model_save_path, 'vgg16.0.2perfect_finetuned_model.keras'))
print("✅ Modèle enregistré avec succès dans pc.")
# Out:
# ✅ Modèle enregistré avec succès dans pc.

# %%
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, f1_score
#preparation de donnees
train_dir = 'D:/Data-Chest-ray/train'
val_dir = 'D:/Data-Chest-ray/val'
test_dir = 'D:/Data-Chest-ray/test'
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=15,
                                   zoom_range=0.1,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1)
val_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(train_dir, target_size=IMG_SIZE,
                                              batch_size=BATCH_SIZE, class_mode='categorical')
val_gen = val_datagen.flow_from_directory(val_dir, target_size=IMG_SIZE,
                                          batch_size=BATCH_SIZE, class_mode='categorical')
test_gen = val_datagen.flow_from_directory(test_dir, target_size=IMG_SIZE,
                                           batch_size=1, class_mode='categorical', shuffle=False)
#Entraînement initial (feature extraction)

base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

model = models.Sequential([
    base_model,
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.7),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.7),
    layers.Dense(train_gen.num_classes, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history_1 = model.fit(train_gen,
                      validation_data=val_gen,
                      epochs=20,
                      callbacks=[early_stop])
#Fine-tuning
# Débloquer les dernières couches de VGG16
base_model.trainable = True
for layer in base_model.layers[:-4]:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=1e-5),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history_2 = model.fit(train_gen,
                      validation_data=val_gen,
                      epochs=15,
                      callbacks=[early_stop])

# Prédictions
pred_probs = model.predict(test_gen)
y_pred = np.argmax(pred_probs, axis=1)
y_true = test_gen.classes
target_names = list(test_gen.class_indices.keys())

# Rapport de classification
print(classification_report(y_true, y_pred, target_names=target_names))

# F1-score
f1 = f1_score(y_true, y_pred, average='macro')
print("F1-score (macro):", f1)

# Matrice de confusion
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Courbes ROC pour chaque classe
fpr, tpr, roc_auc = dict(), dict(), dict()
for i in range(len(target_names)):
    fpr[i], tpr[i], _ = roc_curve(test_gen.labels == i, pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure()
for i in range(len(target_names)):
    plt.plot(fpr[i], tpr[i], label=f'{target_names[i]} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (per class)')
plt.legend()
plt.grid(True)
plt.show()
def plot_learning_curves(history_list, labels):
    acc = []
    val_acc = []
    loss = []
    val_loss = []

    for hist in history_list:
        acc += hist.history['accuracy']
        val_acc += hist.history['val_accuracy']
        loss += hist.history['loss']
        val_loss += hist.history['val_loss']

    epochs_range = range(1, len(acc)+1)

    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# Appeler la fonction
plot_learning_curves([history_1, history_2], ['Phase 1', 'Phase 2'])
# Out:
# Found 7750 images belonging to 2 classes.
# Found 744 images belonging to 2 classes.
# Found 364 images belonging to 2 classes.
# C:\Users\Bsi\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 600s 2s/step - accuracy: 0.7287 - loss: 0.6058 - val_accuracy: 0.8656 - val_loss: 0.2886
# Epoch 2/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 588s 2s/step - accuracy: 0.8917 - loss: 0.2830 - val_accuracy: 0.9126 - val_loss: 0.2135
# Epoch 3/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 586s 2s/step - accuracy: 0.9120 - loss: 0.2432 - val_accuracy: 0.9153 - val_loss: 0.1751
# Epoch 4/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 586s 2s/step - accuracy: 0.9294 - loss: 0.2080 - val_accuracy: 0.9194 - val_loss: 0.1594
# Epoch 5/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 590s 2s/step - accuracy: 0.9289 - loss: 0.1944 - val_accuracy: 0.9220 - val_loss: 0.1475
# Epoch 6/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 579s 2s/step - accuracy: 0.9419 - loss: 0.1735 - val_accuracy: 0.9651 - val_loss: 0.1476
# Epoch 7/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 583s 2s/step - accuracy: 0.9419 - loss: 0.1597 - val_accuracy: 0.9207 - val_loss: 0.1268
# Epoch 8/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 579s 2s/step - accuracy: 0.9423 - loss: 0.1597 - val_accuracy: 0.9704 - val_loss: 0.1228
# Epoch 9/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 615s 3s/step - accuracy: 0.9487 - loss: 0.1643 - val_accuracy: 0.9677 - val_loss: 0.1394
# Epoch 10/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 609s 3s/step - accuracy: 0.9456 - loss: 0.1625 - val_accuracy: 0.9355 - val_loss: 0.1132
# Epoch 11/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 604s 2s/step - accuracy: 0.9526 - loss: 0.1348 - val_accuracy: 0.9664 - val_loss: 0.1162
# Epoch 12/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 613s 3s/step - accuracy: 0.9560 - loss: 0.1380 - val_accuracy: 0.9382 - val_loss: 0.1566
# Epoch 13/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 618s 3s/step - accuracy: 0.9508 - loss: 0.1413 - val_accuracy: 0.9677 - val_loss: 0.1089
# Epoch 14/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 615s 3s/step - accuracy: 0.9500 - loss: 0.1359 - val_accuracy: 0.9677 - val_loss: 0.1159
# Epoch 15/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 611s 3s/step - accuracy: 0.9573 - loss: 0.1246 - val_accuracy: 0.9677 - val_loss: 0.1158
# Epoch 16/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 601s 2s/step - accuracy: 0.9557 - loss: 0.1250 - val_accuracy: 0.9852 - val_loss: 0.1002
# Epoch 17/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 591s 2s/step - accuracy: 0.9549 - loss: 0.1267 - val_accuracy: 0.9368 - val_loss: 0.1404
# Epoch 18/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 594s 2s/step - accuracy: 0.9569 - loss: 0.1183 - val_accuracy: 0.9382 - val_loss: 0.1121
# Epoch 19/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 589s 2s/step - accuracy: 0.9552 - loss: 0.1249 - val_accuracy: 0.9382 - val_loss: 0.1137
# Epoch 20/20
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 579s 2s/step - accuracy: 0.9596 - loss: 0.1214 - val_accuracy: 0.9825 - val_loss: 0.0935
# Epoch 1/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 666s 3s/step - accuracy: 0.9660 - loss: 0.1011 - val_accuracy: 0.9852 - val_loss: 0.1076
# Epoch 2/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 668s 3s/step - accuracy: 0.9739 - loss: 0.0792 - val_accuracy: 0.9462 - val_loss: 0.1328
# Epoch 3/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 668s 3s/step - accuracy: 0.9730 - loss: 0.0771 - val_accuracy: 0.9785 - val_loss: 0.0979
# Epoch 4/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 664s 3s/step - accuracy: 0.9770 - loss: 0.0708 - val_accuracy: 0.9852 - val_loss: 0.1000
# Epoch 5/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 693s 3s/step - accuracy: 0.9806 - loss: 0.0548 - val_accuracy: 0.9758 - val_loss: 0.1214
# Epoch 6/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 683s 3s/step - accuracy: 0.9809 - loss: 0.0649 - val_accuracy: 0.9825 - val_loss: 0.0992
# Epoch 7/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 676s 3s/step - accuracy: 0.9810 - loss: 0.0505 - val_accuracy: 0.9772 - val_loss: 0.1304
# Epoch 8/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 671s 3s/step - accuracy: 0.9806 - loss: 0.0586 - val_accuracy: 0.9355 - val_loss: 0.2348
# 364/364 ━━━━━━━━━━━━━━━━━━━━ 47s 129ms/step
#               precision    recall  f1-score   support
#
#       NORMAL       0.95      0.81      0.88       182
#    PNEUMONIA       0.83      0.96      0.89       182
#
#     accuracy                           0.88       364
#    macro avg       0.89      0.88      0.88       364
# weighted avg       0.89      0.88      0.88       364
#
# F1-score (macro): 0.8839285714285714
